# %%
import slicersim

# %%
from slicersim.extra.calspec import calspecsource as cl_source

# %%
bd17 = cl_source.get_data("bd_17")

# %%
calspec = slicersim.LazuliCalSpec("bd_17")

# %%
calspec.setup_to_snr(10)
# Out:
# WARNING: SaturationWarning: 16196 detector px above 65635 ADU. [slicersim.detector]
# WARNING: SaturationWarning: 14028 detector px above 65635 ADU. [slicersim.detector]
# WARNING: SaturationWarning: 13916 detector px above 65635 ADU. [slicersim.detector]
# WARNING: SaturationWarning: 13728 detector px above 65635 ADU. [slicersim.detector]
# WARNING: SaturationWarning: 13272 detector px above 65635 ADU. [slicersim.detector]
# WARNING: SaturationWarning: 12176 detector px above 65635 ADU. [slicersim.detector]
# WARNING: SaturationWarning: 4304 detector px above 65635 ADU. [slicersim.detector]
# ({'nmd': (2, 8, 0), 'nramp': 1}, 402.54644124552465)

# %%
lbda, spec, var = calspec.get_spectrum()
# Out:
# WARNING: SaturationWarning: 4304 detector px above 65635 ADU. [slicersim.detector]

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.plot(lbda, spec)

# %% [markdown]
# # BD 17 from CalSpec

# %%
calspec_bd17 = "https://archive.stsci.edu/hlsps/reference-atlases/cdbs/current_calspec/bd_17d4708_stisnic_007.fits"

# %%
bd17 = pandas.DataFrame( fits.open(calspec_bd17)[1].data )
bd17 = bd17.set_index(bd17.index.values)
bd17.head()
# Out:
#     WAVELENGTH          FLUX     STATERROR      SYSERROR      FWHM  DATAQUAL  \
# 0  1710.574707  2.556900e-14  2.949600e-15  2.556900e-16  2.742676         1
# 1  1711.946045  1.637600e-14  2.762800e-15  1.637600e-16  2.742676         1
# 2  1713.317383  1.672700e-14  2.740600e-15  1.672700e-16  2.742676         1
# 3  1714.688721  2.120700e-14  2.702000e-15  2.120700e-16  2.742798         1
# 4  1716.060181  2.432100e-14  2.707700e-15  2.432100e-16  2.742798         1
#
#    TOTEXP
# 0  2913.0
# 1  2913.0
# 2  2913.0
# 3  2913.0
# 4  2913.0

# %%
flag = bd17["WAVELENGTH"].between(3_000, 20_000).astype(bool).values
lbda_ref = bd17["WAVELENGTH"].astype(float).values[flag]
flux_ref = bd17["FLUX"].astype(float).values[flag]

# %%
from slicersim import Simulation

# %%
sim = Simulation.from_source(lbda_ref, flux_ref, background="zodi")

# %%
sim.show_spectrum()
# Out:
# WARNING: SaturationWarning: 22208 detector px above 65635 ADU. [slicersim.detector]
# WARNING: SaturationWarning: 5656 spectral px above 65635 ADU. [slicersim.detector]
# <Axes: xlabel='Obsframe wavelength [µm]', ylabel='Signal [ADU]'>
